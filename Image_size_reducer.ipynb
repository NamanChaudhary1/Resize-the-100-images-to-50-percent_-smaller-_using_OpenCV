# %% [markdown]
# <a href="https://colab.research.google.com/github/NamanChaudhary1/Resize-the-100-images-to-50-percent_-smaller-_using_OpenCV/blob/main/Image_size_reducer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import cv2
import os
import numpy as np
from urllib.parse import urlparse

def download_and_resize_images(url, output_dir):
    # Send a GET request to the web page URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content
        html_content = response.text

        # Create the output directories if they don't exist
        downloaded_dir = os.path.join(output_dir, "downloaded_images")
        resized_dir = os.path.join(output_dir, "resized_images")
        os.makedirs(downloaded_dir, exist_ok=True)
        os.makedirs(resized_dir, exist_ok=True)

        # Extract image URLs from the HTML content
        image_urls = extract_image_urls(html_content)

        # Download and resize the images
        for i, image_url in enumerate(image_urls):
            if i >= 100:
                break

            try:
                # Send a GET request to download the image
                response = requests.get(image_url)
                response.raise_for_status()

                # Decode the image data
                image_data = response.content

                # Check if the image data is not empty
                if image_data:
                    # Read the image with OpenCV
                    image = cv2.imdecode(np.frombuffer(image_data, np.uint8), cv2.IMREAD_COLOR)

                    # Check if the image is valid
                    if image is not None:
                        # Resize the image to 50% of its original size
                        resized_image = cv2.resize(image, (0, 0), fx=0.5, fy=0.5)

                        # Save the downloaded image
                        downloaded_image_path = os.path.join(downloaded_dir, f"image_{i}.jpg")
                        with open(downloaded_image_path, "wb") as f:
                            f.write(image_data)

                        # Save the resized image
                        resized_image_path = os.path.join(resized_dir, f"image_{i}.jpg")
                        cv2.imwrite(resized_image_path, resized_image)

                        print(f"Downloaded and resized image {i}")

                    else:
                        print(f"Invalid image at URL {image_url}")

                else:
                    print(f"Empty image data at URL {image_url}")

            except requests.exceptions.HTTPError as e:
                print(f"Failed to download image at URL {image_url}: {e}")
            except cv2.error as e:
                print(f"Failed to resize image at URL {image_url}: {e}")
            except Exception as e:
                print(f"An error occurred while processing image at URL {image_url}: {e}")

    else:
        print(f"Failed to retrieve web page. Status code: {response.status_code}")

def extract_image_urls(html_content):
    # Use your preferred method to extract image URLs from the HTML content
    # Here's an example using BeautifulSoup:
    from bs4 import BeautifulSoup

    soup = BeautifulSoup(html_content, "html.parser")
    image_tags = soup.find_all("img")
    image_urls = [tag.get("src") for tag in image_tags]
    return image_urls

# Define the URL of the web page containing the images
url = "https://unsplash.com"

# Define the output directory to save the downloaded and resized images
output_dir = "content"

# Download and resize the images
download_and_resize_images(url, output_dir)
# Out:
# Invalid image at URL https://sb.scorecardresearch.com/p?c1=2&c2=32343279&cv=2.0&cj=1
# Downloaded and resized image 1
# Downloaded and resized image 2
# Downloaded and resized image 3
# Downloaded and resized image 4
# Downloaded and resized image 5
# Downloaded and resized image 6
# Downloaded and resized image 7
# Downloaded and resized image 8
# Downloaded and resized image 9
# Downloaded and resized image 10
# Downloaded and resized image 11
# Downloaded and resized image 12
# Downloaded and resized image 13
# Downloaded and resized image 14
# Downloaded and resized image 15
# Downloaded and resized image 16
# Downloaded and resized image 17
# Downloaded and resized image 18
# Downloaded and resized image 19
# Downloaded and resized image 20
# Downloaded and resized image 21
# Downloaded and resized image 22
# Downloaded and resized image 23
# Downloaded and resized image 24
# Downloaded and resized image 25
# Downloaded and resized image 26
# Downloaded and resized image 27
# Downloaded and resized image 28
# Downloaded and resized image 29
# Downloaded and resized image 30
# Downloaded and resized image 31
# Downloaded and resized image 32
# Downloaded and resized image 33
# Downloaded and resized image 34
# Downloaded and resized image 35
# Downloaded and resized image 36
# Downloaded and resized image 37
# Downloaded and resized image 38
# Downloaded and resized image 39
# Downloaded and resized image 40
# Downloaded and resized image 41
# Downloaded and resized image 42
# Downloaded and resized image 43
# Downloaded and resized image 44
# Downloaded and resized image 45
# Downloaded and resized image 46
# Downloaded and resized image 47
# Downloaded and resized image 48
# Downloaded and resized image 49
# Downloaded and resized image 50
# Downloaded and resized image 51
# Downloaded and resized image 52
# Downloaded and resized image 53
# Downloaded and resized image 54
# Downloaded and resized image 55
# Downloaded and resized image 56
# Downloaded and resized image 57
# Downloaded and resized image 58
# Downloaded and resized image 59
# Downloaded and resized image 60
# Downloaded and resized image 61
# Downloaded and resized image 62
# Downloaded and resized image 63
# Downloaded and resized image 64
# Downloaded and resized image 65
# Downloaded and resized image 66
# Downloaded and resized image 67
# Downloaded and resized image 68
# Downloaded and resized image 69
# Downloaded and resized image 70
# Downloaded and resized image 71
# Downloaded and resized image 72
# Downloaded and resized image 73
# Downloaded and resized image 74
# Downloaded and resized image 75
# Downloaded and resized image 76
# Downloaded and resized image 77
# Downloaded and resized image 78
# Downloaded and resized image 79
# Downloaded and resized image 80
# Downloaded and resized image 81
# Downloaded and resized image 82
# Downloaded and resized image 83
# Downloaded and resized image 84
# Downloaded and resized image 85
# Downloaded and resized image 86
# Downloaded and resized image 87
# Downloaded and resized image 88
# Downloaded and resized image 89
# Downloaded and resized image 90
# Downloaded and resized image 91
# Downloaded and resized image 92
# Downloaded and resized image 93
# Downloaded and resized image 94
# Downloaded and resized image 95
# Downloaded and resized image 96
# Downloaded and resized image 97
# Invalid image at URL https://secure.insightexpressai.com/adServer/adServerESI.aspx?script=false&bannerID=11051621&rnd=1686943863046&redir=https://secure.insightexpressai.com/adserver/1pixel.gif
# Invalid image at URL https://secure.insightexpressai.com/adServer/adServerESI.aspx?script=false&bannerID=11345018&rnd=1686943863046&redir=https://secure.insightexpressai.com/adserver/1pixel.gif
